# %%
import pickle
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = open('../data/ingr_map.pkl', 'rb')

# %%
data = pickle.load(file)

# %%
file.close()
print('Showing the pickled data:')
# Out:
# Showing the pickled data:

# %%
print(len(data))
# Out:
# 11659

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.head(20)
# Out:
#                                              raw_ingr  raw_words  \
# 0   medium heads bibb or red leaf lettuce, washed,...         13
# 1               mixed baby lettuces and spring greens          6
# 2                                romaine lettuce leaf          3
# 3                                iceberg lettuce leaf          3
# 4                                 red romaine lettuce          3
# 5                                head romaine lettuce          3
# 6                                curly endive lettuce          3
# 7                              romaine lettuce hearts          3
# 8                                   baby leaf lettuce          3
# 9                                     head of lettuce          3
# 10                               head iceberg lettuce          3
# 11                                boston lettuce leaf          3
# 12                                   heads of lettuce          3
# ...

# %%
data.tail(20)
# Out:
#             raw_ingr  raw_words     processed  len_proc      replaced  count  \
# 11639       absinthe          1      absinthe         8      absinthe      2
# 11640     shortcakes          1     shortcake         9     shortcake      6
# 11641         gluten          1        gluten         6        gluten     59
# 11642       bluefish          1      bluefish         8      bluefish      3
# 11643  quatre-epices          1  quatre-epice        12  quatre-epice      2
# 11644      rambutans          1      rambutan         8      rambutan      2
# 11645       semolina          1      semolina         8      semolina     87
# 11646       bresaola          1      bresaola         8      bresaola      2
# 11647          roast          1         roast         5         roast     74
# 11648     condiments          1     condiment         9     condiment     15
# 11649     broccolini          1    broccolini        10    broccolini     26
# ...

# %%
recipe = pd.read_csv()
