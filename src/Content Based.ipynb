# %%
import pandas as pd
import re

# %%
df = pd.read_csv('../dataset/preprocessed_data.csv')
df
# Out:
#         user_id  recipe_id        date  rating  \
# 0           498      20979  2002-12-01       4
# 1          8271      65604  2005-09-02       4
# 2         28906      65604  2005-12-22       5
# 3         36667      65604  2006-09-26       5
# 4         20362      65604  2007-03-09       5
# ...         ...        ...         ...     ...
# 975854    10856      25877  2007-04-26       0
# 975855    53481     168130  2009-09-29       5
# 975856    16646      37518  2008-06-23       5
# 975857     5495      37518  2009-01-11       4
# 975858   186934      37518  2017-12-18       5
#
#                                                    review  minutes  \
# 0       this worked very well and is easy. i used not ...       20
# 1                                               very good       40
# 2                                    better than the real       40
# 3       absolutely awesome i was speechless when i tri...       40
# ...
